# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
int(np.ceil(df_ints.shape[1]/2))
# Out:
# 4

# %%
df_obj = df.select_dtypes(include='object')

# %%
def box_plot(df):
    
    df_obj = df.select_dtypes(include='object')
    df_ints = df.drop(df_obj.columns,axis = 1)
    
    n = int(np.ceil(df_ints.shape[1]/2))
    
    fig, axes = plt.subplots(n,2, figsize = (16,6*n))
    fig.suptitle('Useful Boxplots', fontsize = 18)
    c = 0
    for i in range(0,n):
        sns.boxplot(data = df_ints, x = df_ints.columns[c], ax = axes[i,0])
        sns.boxplot(data = df_ints, x = df_ints.columns[c+1], ax = axes[i,1])
        c = c + 2
    plt.show()

# %%
box_plot(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-f8ece9716f67> in <module>
# ----> 1 box_plot(df)
#
# <ipython-input-41-76df972238f5> in box_plot(df)
#      11     for i in range(0,n):
#      12         sns.boxplot(data = df_ints, x = df_ints.columns[c], ax = axes[i,0])
# ---> 13         sns.boxplot(data = df_ints, x = df_ints.columns[c+1], ax = axes[i,1])
#      14         c = c + 2
#      15     plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4295         if is_scalar(key):
#    4296             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4297             return getitem(key)
#    4298
#    4299         if isinstance(key, slice):
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %%
df_ints = df.drop(df_obj.columns,axis = 1)

# %%
np.ceil(df_ints.shape[1]/2)
# Out:
# 4.0

# %%
df_ints.columns[0]
# Out:
# 'PassengerId'

# %%
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]
